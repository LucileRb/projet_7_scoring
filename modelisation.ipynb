# %%
########## Imports ##########
import numpy as np
import pandas as pd

import pickle
import os

from sklearn.model_selection import train_test_split

# %%
########## Import des données ##########

path = '' #-> en local
filepath = os.path.join(path, 'df_train_clean')

with open(filepath, 'rb') as f:
    df = pickle.load(f)

df.head()
# Out:
#             NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# SK_ID_CURR
# 100002.0                   0.0          1.0           0.0              1.0
# 100003.0                   0.0          0.0           0.0              0.0
# 100004.0                   1.0          1.0           1.0              1.0
# 100006.0                   0.0          0.0           0.0              1.0
# 100007.0                   0.0          1.0           0.0              1.0
#
#             CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100002.0             0.0          0.001512    0.090287     0.090032
# 100003.0             0.0          0.002089    0.311736     0.132924
# 100004.0             0.0          0.000358    0.022472     0.020025
# 100006.0             0.0          0.000935    0.066837     0.109477
# 100007.0             0.0          0.000819    0.116854     0.078975
#
#             AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  ...  \
# SK_ID_CURR                                               ...
# 100002.0           0.077441                    0.256321  ...
# 100003.0           0.271605                    0.045016  ...
# 100004.0           0.023569                    0.134897  ...
# 100006.0           0.063973                    0.107023  ...
# 100007.0           0.117845                    0.392880  ...
#
#             HOUSETYPE_MODE_nan  WALLSMATERIAL_MODE_Block  \
# SK_ID_CURR
# 100002.0                   0.0                       0.0
# 100003.0                   0.0                       1.0
# 100004.0                   1.0                       0.0
# 100006.0                   1.0                       0.0
# 100007.0                   1.0                       0.0
#
#             WALLSMATERIAL_MODE_Mixed  WALLSMATERIAL_MODE_Monolithic  \
# SK_ID_CURR
# 100002.0                         0.0                            0.0
# 100003.0                         0.0                            0.0
# 100004.0                         0.0                            0.0
# 100006.0                         0.0                            0.0
# 100007.0                         0.0                            0.0
#
#             WALLSMATERIAL_MODE_Others  WALLSMATERIAL_MODE_Panel  \
# SK_ID_CURR
# 100002.0                          0.0                       0.0
# 100003.0                          0.0                       0.0
# 100004.0                          0.0                       0.0
# 100006.0                          0.0                       0.0
# 100007.0                          0.0                       0.0
#
#             WALLSMATERIAL_MODE_Stone, brick  WALLSMATERIAL_MODE_Wooden  \
# SK_ID_CURR
# 100002.0                                1.0                        0.0
# 100003.0                                0.0                        0.0
# 100004.0                                0.0                        0.0
# 100006.0                                0.0                        0.0
# 100007.0                                0.0                        0.0
#
#             WALLSMATERIAL_MODE_nan  TARGET
# SK_ID_CURR
# 100002.0                       0.0     1.0
# 100003.0                       0.0     0.0
# 100004.0                       1.0     0.0
# 100006.0                       1.0     0.0
# 100007.0                       1.0     0.0
#
# [5 rows x 258 columns]

# %%
# Séparation en train et en test

X = df.drop(columns = 'TARGET')
y = df['TARGET']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# on remet la target dans les données ?
X_train['TARGET'] = y_train
X_test['TARGET'] = y_test

# %%
print('train shape :', X_train.shape)
print('test shape :', X_test.shape)
# Out:
# train shape : (246004, 258)
# test shape : (61501, 258)
